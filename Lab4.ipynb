# %% [markdown]
# ## MATH 151 Lab 4
#
# Names of team members: Kevin Ngo, Elias Ramos, Edward Hirs, Emily

# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)

# %% [markdown]
# #1

# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)
x = symbols('x')
x1 = 0
y1 = 2
fun = x**4+2*E**x
dfun = diff(fun, x)
m = dfun.subs(x, 0)
print ('The derivative of f(x) ', fun)
print ('The derivative of f(0) ', m)
y = m*(x-x1)+y1
nfun = y.subs(m, 2)
print ('The equation for the tangent line at the point, y =', nfun)
iy = (-1*m)*(x-x1)+y1
infun = iy.subs(im, 2)
print ('This is the invert equation of the tangent line, y =', infun)
fplot = plot(y,iy,fun,(x,-1,1))
# Out:
# The derivative of f(x)  x**4 + 2*exp(x)
# The derivative of f(0)  2
# The equation for the tangent line at the point, y = 2*x + 2
# This is the invert equation of the tangent line, y = -2*x + 2

# %% [markdown]
# #2

# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)
#part a
x = Symbol ('x')
f_x = (x / (1 + x**2))
f_3  =f_x.subs(x, 3)
print ("f(3) = ", f_3)
f_prime_x = diff(f_x)
print ("f'(x) = ", f_prime_x)
derivative = f_prime_x.subs(x, 3)
print ("f'(3) =", derivative )
tangent_equation = ((derivative * (x - 3)) + f_3)


print ("y = ", tangent_equation)
#part b
plot1 = plot(tangent_equation, f_x,(x,0,5))
# Out:
# f(3) =  3/10
# f'(x) =  -2*x**2/(x**2 + 1)**2 + 1/(x**2 + 1)
# f'(3) = -2/25
# y =  -2*x/25 + 27/50

# %% [markdown]
# #3

# %%
from sympy import*
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)
x = symbols('x')
g_x = x/exp(x)
g_prime_1 = diff(g_x, x)
g_prime_2 = simplify(diff(g_prime_1, x))
g_prime_3 = simplify(diff(g_prime_2, x))
g_prime_4 = simplify(diff(g_prime_3, x))
g_prime_5 = simplify(diff(g_prime_4, x))
print ("g'(x) =", g_prime_1)
print ("g''(x) =", g_prime_2)
print ("g'''(x) =", g_prime_3)
print ("g''''(x) =", g_prime_4)
print ("g'''''(x) =", g_prime_5)
print ("The formula for the nth derivative of g(x) is [(-1)**n+1) * n + ((-1)**n)] * (e**-n)")
# Out:
# g'(x) = -x*exp(-x) + exp(-x)
# g''(x) = (x - 2)*exp(-x)
# g'''(x) = (-x + 3)*exp(-x)
# g''''(x) = (x - 4)*exp(-x)
# g'''''(x) = (-x + 5)*exp(-x)
# The formula for the nth derivative of g(x) is [(-1)**n+1) * n + ((-1)**n)] * (e**-n)

# %% [markdown]
# #4

# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)
import math
import numpy as np
print("a)")
x = symbols('x')
f = x/(1 - cos(2*x))**(1/2)
plot1 = plot(f, (x, -3, 3), show=false)
plot1.show()

print(" ")

print('b)')
for x in [-0.1,-0.01,-0.001,0.1,0.01,0.001]:
    f = x/(1 - cos(2*x))**(1/2)
    print(f)
print("We can estimate that the limit from the left of 0 is -0.7 and that the limit from the right is 0.7.")

print(" ")

print("c)")
a = symbols('a')
expr = a*(1 - cos(2*a)**(-1/2))
lim1 = Limit(expr, a, 0, '+')
lim2 = Limit(expr, a, 0, '-')
print(lim1)
print(lim2)

print(" ")

print("d)")
g = x**2/(1-cos(2*x))
lim3 = limit(g, x, 0) 
print(lim3)
print("The limit of f at 0 does not exist because the limit of 0- and 0+ are not equal.")
# Out:
# a)
#
# b)
# -0.708286668869620
# -0.707118566437023
# -0.707106899031475
# 0.708286668869620
# 0.707118566437023
# 0.707106899031475
# We can estimate that the limit from the left of 0 is -0.7 and that the limit from the right is 0.7.
#
# c)
# Limit(a*(-cos(2*a)**(-0.5) + 1), a, 0)
# Limit(a*(-cos(2*a)**(-0.5) + 1), a, 0, dir='-')
#
# d)
# 0.500000166657909
# The limit of f at 0 does not exist because the limit of 0- and 0+ are not equal.

# %% [markdown]
# #5

# %%
# Insert code for problem #5 here.  
# Obviously, if there is NO problem #5, you may delete this cell (under "Edit" above)
